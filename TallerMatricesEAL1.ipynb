# %% [markdown]
# #Taller de matrices

# %% [markdown]
# ##9.1)
# ###a)
# $\begin{pmatrix}
# 0 & 2 & 5 \\
# 1 & 0 & 1 \\
# 8 & 3 & 0
# \end{pmatrix}$
# $\begin{pmatrix}
# x_1 \\
# x_2 \\
# x_3
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 50  \\
# 10 \\
# 20
# \end{pmatrix}$
#
# ###b)
# $\begin{pmatrix}
# 0 & 1 & 8 \\
# 2 & 0 & 3 \\
# 5 & 1 & 0
# \end{pmatrix}$
#
# #----------------------------------------------------------------------------------------

# %% [markdown]
# ##9.2)
# ###a)
# [A]=3x2
#
# [B]=3x3
#
# [C]=3x1
#
# [D]=2x4
#
# [E]=3x3
#
# [F]=2x3
#
# [G]=1x3
#
# ###b)
# Cuadradas:
# [B] Y [E]
#
# Columna:
# [C]
#
# Renglon:
# [G]
#
# ###c)
#
# a12=7
#
# b23=7
#
# d32=No existe esa poscicion
#
# e22=2
#
# f12=0
#
# g12=6
#
# ###d)
# ####1)
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
# +
# $\begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 5 & 8 & 15 \\
# 8 & 4 & 10 \\
# 5 & 0 & 10
# \end{pmatrix}$
# ####2)
# No es posible sumar dos matrices de dimenciones diferentes
#
# ####3)
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
# -
# $\begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 3 & -2 & -1 \\
# -6 & 0 & 4 \\
# -3 & 0 & -2
# \end{pmatrix}$
#
# ####4)
# 7
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 28 & 21 & 49 \\
# 7 & 14 & 49 \\
# 7 & 0 & 28
# \end{pmatrix}$
#
# ####5)
# $\begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}$
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 17 & 13 & 74 \\
# 33 & 25 & 75 \\
# 22 & 12 & 52
# \end{pmatrix}$
#
# C11= 1*4 + 5*1 + 8*1 = 4 + 5 + 8 = 17
#
# C12= 1*3 + 5*2 + 8*0 = 3 + 10 + 0 = 13
#
# C13= 1*7 + 5*7 + 8*4 = 7 + 35 + 32 = 74
#
# C21= 7*4 + 2*1 + 3*1 = 28 + 2 + 3 = 33
#
# C22= 7*3 + 2*2 + 3*0 = 21 + 4 + 0 = 25
#
# C23= 7*7 + 2*7 + 3*4 = 49 + 14 + 12 = 75
#
# C31= 4*4 + 0*1 + 6*1 = 16 + 0 + 6 = 22
#
# C32= 4*3 + 0*2 + 6*0 = 12 + 0 + 0 = 12
#
# C33= 4*7 + 0*7 + 6*4 = 28 + 0 + 24 = 52
#
# ####6)
# $\begin{pmatrix}
# 3  \\
# 6  \\
# 1
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 3 & 6 & 1 \\
# \end{pmatrix}^{\text{T}}$
#
# ####7)
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
# $\begin{pmatrix}
# 4 & 7 \\
# 1 & 2 \\
# 5 & 6
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 54 & 76 \\
# 41 & 53 \\
# 24 & 31
# \end{pmatrix}$
#
# C11 = 4*4 + 3*1 + 7*5 = 16 + 3 + 35 = 54
#
# C12= 4*7 + 3*2 + 7*6 = 28 + 6 + 42 = 76
#
# C21 = 1*4 + 2*1 + 7*5 = 4 + 2 + 35 = 41
#
# C22 = 1*7 + 2*2 + 7*6 = 7 + 4 + 42 = 53
#
# C31 = 1*4 + 0*1 + 4*5 = 4 + 0 + 20 = 24
#
# C32 = 1*7 + 0*2 + 4*6 = 7 + 0 + 24 = 31
#
# ####8)
# $\begin{pmatrix}
# 9 & 4 & 3 & -6 \\
# 2 & -1 & 7 & 5 \\
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 9 & 2 \\
# 4 & -1 \\
# 3 & 7 \\
# -6 & 5
# \end{pmatrix}^{\text{T}}$
#
# ####9)
# No cumple la condicion de #columna = #fila
#
# ####10)
# $\begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{pmatrix}$
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 4 & 3 & 7 \\
# 1 & 2 & 7 \\
# 1 & 0 & 4
# \end{pmatrix}$
#
# ####11)
# $\begin{pmatrix}
# 1 & 5 & 8 \\
# 7 & 2 & 3 \\
# 4 & 0 & 6
# \end{pmatrix}$
# $\begin{pmatrix}
# 1 & 7 & 4 \\
# 5 & 2 & 0 \\
# 8 & 3 & 6
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 66 & 19 & 52\\
# 19 & 62 & 46 \\
# 52 & 46 & 109
# \end{pmatrix}$
#
# ####12)
# $\begin{pmatrix}
# 3 & 6 & 1 \\
# \end{pmatrix}^{\text{T}}$
# $\begin{pmatrix}
# 3  \\
# 6  \\
# 1
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 46
# \end{pmatrix}$
#
# C11= 3*3 + 6*6 + 1*1 = 9 + 36 + 1 = 46
#
# #------------------------------------------------------------------------------------------

# %% [markdown]
# ##9.3)
#
# [a]=
# $\begin{pmatrix}
# 1 & 6\\
# 3 & 10 \\
# 7 & 4
# \end{pmatrix}$
#   [B]=
# $\begin{pmatrix}
# 1 & 3\\
# 0.5 & 2
# \end{pmatrix}$
#   [C]=
# $\begin{pmatrix}
# 2 & -2\\
# -3 & 1
# \end{pmatrix}$
#
# ###a)
# [A]x[B]
#
# $\begin{pmatrix}
# 1 & 6\\
# 3 & 10 \\
# 7 & 4
# \end{pmatrix}$
# $\begin{pmatrix}
# 1 & 3\\
# 0.5 & 2
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 4 & 15 \\
# 8 & 29 \\
# 9 & 29
# \end{pmatrix}$
#
# [B]x[C]
#
# $\begin{pmatrix}
# 1 & 3\\
# 0.5 & 2
# \end{pmatrix}$
# $\begin{pmatrix}
# 2 & -2\\
# -3 & 1
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# -7 & 1\\
# -5 & 1
# \end{pmatrix}$
#
# [A]x[C]
#
# $\begin{pmatrix}
# 1 & 6\\
# 3 & 10 \\
# 7 & 4
# \end{pmatrix}$
# $\begin{pmatrix}
# 2 & -2\\
# -3 & 1
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# -16 & 4 \\
# -24 & 4 \\
# 2 & -10
# \end{pmatrix}$
#
# [C]x[B]
#
# $\begin{pmatrix}
# 2 & -2\\
# -3 & 1
# \end{pmatrix}$
# $\begin{pmatrix}
# 1 & 3\\
# 0.5 & 2
# \end{pmatrix}$
# =
# $\begin{pmatrix}
# 1 & 2\\
# -2.5 & -7
# \end{pmatrix}$
#
# ###b)
#
# De acuerdo con la definición, la multiplicación de dos matrices se puede realizar
# sólo si la primera matriz tiene tantas columnas como el número de renglones en la segun-
# da matriz, entonces por regla descartamos las combinaciones que no la cumplen.
#
# ###c)
#
#
#
# #----------------------------------------------------------------------------------------------

# %% [markdown]
# ##9.4)

# %%
import numpy as np
import matplotlib.pyplot as plt

def f1(x):
    x1=-6+(2*x)
    return x1

def f2(xi):
    x11=34-6*xi
    return x11

xxg=[]
xg=[]
var=[]
i=4.8
while(i<=5.2):
    xg.append(f1(i))
    xxg.append(f2(i))
    var.append(i)
    i=i+0.2

plt.plot(var,xg,'r')
plt.plot(var,xxg,'b')
plt.grid()
plt.show()

x1=-6+(2*5)
x11=34-6*5
 
print "x1= %d  x11= %d" %(x1,x11)
# Out:
# x1= 4  x11= 4

# %% [markdown]
# #----------------------------------------------------------------------------------------
#
# ##9.5)

# %%
import numpy as np
import matplotlib.pyplot as plt

def MetodoGrafica()():
    x=350
    Gf1= []
    Gf2= []
    Gx = []
    while (x<=1000):
        f1 = (120.0 + 1.1*x)/10.0
        f2 = (174.0 + 2.0*x)/17.4
        Gx.append(x)
        Gf1.append(f1)
        Gf2.append(f2)
        x = x+0.5
    plt.plot(Gx,Gf1)
    plt.plot(Gx,Gf2)
    plt.grid(True)
    plt.show()
    
MetodoGrafica()

# %% [markdown]
# ###a)
#
# Por el metodo grafico, podemos concluir que es un sistema mal condicionado ya que las pendientes son tan cercanas que es dificil encontrar visualmente el punto de intersección.
#
# ###b)
#
# como ya explique antes, el sistema esta mal condicionado, no se puede observar donde se cruzan exactamente las rectas.
#
#
# ###c)
#
# det|A|
# =
# $
# \begin{pmatrix}
# -1.1 & 10\\
# -2 & 17.4
# \end{pmatrix}
# $
# =
# (-1.1)	 * 	(17.4)	 - 	(-2)	 * 	(10)
# =
# 0.86
#
# ###d)
#
# x2 =
# $
# \begin{equation}
# \frac{(-1.1*174) + (2*120)}{(-1.1*17.4) + (10*2)}
# \end{equation}
# $
# =
# 56.5
#
# x1 =
# $
# \begin{equation}
# \frac{(17.4*120) - (10*174)}{(-1.1*17.4) + (10*2)}
# \end{equation}
# $
# =
# 404.65
#
# #-----------------------------------------------------------------------------------------------------

# %% [markdown]
# ##9.6)
#
# ###a)
#
# det|A|
# =
# $
# \begin{pmatrix}
# 0 & 2 & 5\\
# 2 & 1 & 1\\
# 3 & 1 & 0
# \end{pmatrix}
# $
# =
# 1
#
# ###b)
#
# det|A|
# =
# $
# \begin{pmatrix}
# 0 & 2 & 5\\
# 2 & 1 & 1\\
# 3 & 1 & 0
# \end{pmatrix}
# $
# =
# 1
#
# A1
# =
# $
# \begin{pmatrix}
# 9 & 2 & 5\\
# 9 & 1 & 1\\
# 10 & 1 & 0
# \end{pmatrix}
# $
# =
# 6
#
# A2
# =
# $
# \begin{pmatrix}
# 0 & 9 & 5\\
# 2 & 9 & 1\\
# 3 & 10 & 0
# \end{pmatrix}
# $
# =
# -8
#
# A3
# =
# $
# \begin{pmatrix}
# 0 & 2 & 9\\
# 2 & 1 & 9\\
# 3 & 1 & 10
# \end{pmatrix}
# $
# =
# 5
#
# x1 =
# $
# \begin{equation}
# \frac{A1}{det|A|}
# \end{equation}
# $
# =
# 6
#
# x2 =
# $
# \begin{equation}
# \frac{A2}{det|A|}
# \end{equation}
# $
# =
# -8
#
# x3 =
# $
# \begin{equation}
# \frac{A3}{det|A|}
# \end{equation}
# $
# =
# 5
#
# ###c)
#
# 2(-8) + 5(5) = 9
# 2(6) + (-8) + 5 = 9
# 3(6) + (-8) = 10
#
# #------------------------------------------------------------------------------------------------

# %% [markdown]
# ##9.7)

# %%
import numpy as np
import matplotlib.pyplot as plt

def MetodoGrafica():
    x=0.0
    Gf1= []
    Gf2= []
    Gx = []
    while (x<=20):
        f1 = (9.5 + (0.5*x))
        f2 = (18.8 + (1.02*x))/2
        Gx.append(x)
        Gf1.append(f1)
        Gf2.append(f2)
        x = x+0.5
    plt.plot(Gx,Gf1)
    plt.plot(Gx,Gf2)
    plt.grid(True)
    plt.show()
    
MetodoGrafica()

# %% [markdown]
# ###b)
#
# det|A|
# =
# $
# \begin{pmatrix}
# 0.5 & -1\\
# 1.02 & -2
# \end{pmatrix}
# $
# =
# 0.5	 * 	(-2)	 - 	1.02	 * 	(-1)
# =
# 0.02
#
# ###c)
#
# Que por la regla de cramer se hallen los puntos de interseccion & que en los de la grafica no se puedan encontrar por ser un sistema mal condicionado.
#
# ###d)
#
# x1 =
# $
# \begin{equation}
# \frac{((-2)*(-9.5)) - ((-1)*(-18.8))}{(0.5*(-2)) - ((-1)*1.02)}
# \end{equation}
# $
# =
# 10
#
# x2 =
# $
# \begin{equation}
# \frac{(0.5*(-18.8)) - (1.02*(-9.5))}{(0.5*(-2)) - ((-1)*1.02)}
# \end{equation}
# $
# =
# 14.5
#
# ###e)
#
# x1 =
# $
# \begin{equation}
# \frac{((-2)*(-9.5)) - ((-1)*(-18.8))}{(0.52*(-2)) - ((-1)*1.02)}
# \end{equation}
# $
# =
# -10
#
# x2 =
# $
# \begin{equation}
# \frac{(0.52*(-18.8)) - (1.02*(-9.5))}{(0.52*(-2)) - ((-1)*1.02)}
# \end{equation}
# $
# =
# 4.3
#
# #------------------------------------------------------------------------------------------------

# %% [markdown]
# ##9.8)
#
# ###a)
#
# #### Matriz Original
# $\begin{pmatrix}
# 10 & 2 & -3 & 27\\
# -3 & -6 & 2 & -61.5\\
# 1  & 1  & 5 & -21.5
# \end{pmatrix}
# $
#
# ####R1-> (1/10)*R1
# $\begin{pmatrix}
# 1 & 0.2 & -0.3 & 2.7\\
# -3 & -6 & 2 & -61.5\\
# 1  & 1  & 5 & -21.5
# \end{pmatrix}
# $
#
# ####R2->3*R1+R2
# ####R3->(-R1)+R3
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & -27/5 & 17/10 & -267/6\\
# 0 & 4/5  & 51/10 & -121/5
# \end{pmatrix}
# $
#
# ####R2->(-5/27)R2
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & 1 & -17/54 & 89/9\\
# 0 & 4/5  & 51/10 & -121/5
# \end{pmatrix}
# $
#
# ####R3->(-4/5)R2+R3
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & 1 & -17/54 & 89/9\\
# 0 & 0 & 289/54 & -289/9
# \end{pmatrix}
# $
#
# ####R3->(54/289)R3
# $\begin{pmatrix}
# 1 & 1/5 & -1/10 & 27/10\\
# 0 & 1 & -17/54 & 89/9\\
# 0 & 0 & 1 & -6
# \end{pmatrix}
# $
#
# ####Terminado la eliminacion hacia adelante comenzamos con la eliminacion hacia atras
#
# x3=-6
#
# 0 + x2 - 17/54 x3 = 89/9 ----> x2 = 89/9 + (17/54)(-6) = 8
#
# x1 + 1/5 x2 -1/10 x3 = 27/10 ----> x1 = 27/10 - (1/5)(8) + (1/10)(-6) = 1/2
#
#
# ####valores de las incognitas:
#
# X1= 1/2
#
# X2= 8
#
# X3= -6
#
#
# ###b)
#
# 10(1/2) + 2(8) – (-6) = 27
# –3(1/2) – 6(8) + 2(-6) = –61.5
# (1/2) + (8) + 5(-6) = –21.5
